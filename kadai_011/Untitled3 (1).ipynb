# %%
array = ["水","金","地","火","木","土","天","海","冥"]

# --- forループで表示 ---
for item in array:
    print(item)

# --- whileループで表示 ---
i = 0
while i < len(array):
    print(array[i])
    i += 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
